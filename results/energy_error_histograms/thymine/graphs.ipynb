# %%
import os
import sys

style_dir = 'results/mpl_style/physrev_mplstyle/physrev.mplstyle'

from wrappers.orca_wrappers import orca_load
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
import pandas as pd


# %matplotlib inline
# %config InlineBackend.figure_format='retina' 

plt.style.use(style_dir)
plt.rcParams['figure.dpi'] = "300"

# %%
df = pd.read_csv('testing_suite/thymine/results/results.csv')
df
# Out:
#      Unnamed: 0     raw-2  mds-only-2  sf-only-2     mds-2     raw-1  \
# 0             0  0.005554    3.867702   0.229945  1.031494  0.129057
# 1             1  0.048598    3.706334   0.216531  1.005029  0.140353
# 2             2  0.117765    3.881285   0.285301  1.095045  0.141046
# 3             3  0.070227    3.436884   0.212773  1.000371  0.210364
# 4             4  0.139575    3.781511   0.162194  0.990279  0.152575
# ..          ...       ...         ...        ...       ...       ...
# 120         120  0.018265    3.549679   0.177852  1.047095  0.128441
# 121         121  0.220866    3.499616   0.119555  0.917052  0.056700
# 122         122  0.052619    3.691311   0.235037  1.101443  0.223952
# 123         123  0.001864    3.785360   0.275964  1.035098  0.153508
# 124         124  0.073782    3.682437   0.317610  1.048161  0.013313
#
#      mds-only-1  sf-only-1     mds-1
# 0      3.540347   0.323132  1.109588
# 1      3.863541   0.350040  1.183475
# 2      3.442098   0.201242  1.004076
# 3      4.162831   0.451329  1.297349
# 4      3.861615   0.207482  1.036546
# ..          ...        ...       ...
# 120    3.851099   0.355330  1.207861
# 121    4.242001   0.278873  1.063373
# 122    3.800114   0.204427  1.026805
# 123    4.038491   0.380634  1.178203
# 124    3.389917   0.240161  1.035538
#
# [125 rows x 9 columns]

# %%
figure = plt.figure(figsize=(3.5, 2.5))
ax = figure.add_subplot(111)

name_dict = {'raw-1' : 'Scratch Model', 'md-1': 'MD Model', 'isolated-1' : 'SF Model', 'combined-1': 'Combined Model',
             'raw-2' : 'Scratch Model', 'md-2': 'MD Model', 'isolated-2' : 'SF Model', 'combined-2': 'Combined Model'}

rmse_data = []
for column in df.columns[1:5]:
    rmses = df[column].tolist()
    rmse = sum(rmses) / len(rmses)
    model_name = name_dict.get(column, column)  
    rmse_data.append((model_name, rmse))

rmse_data.sort(key=lambda x: x[1])
model_names, rmse_values = zip(*rmse_data)

bars = ax.bar(model_names, rmse_values)

for bar, color in zip(bars, plt.rcParams['axes.prop_cycle'].by_key()['color']):
    bar.set_color(color)

ax.set_ylabel('RMSE')
ax.set_xticklabels(model_names, rotation=45, ha='right')
# Out:
# /tmp/ipykernel_2939943/3504473790.py:23: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(model_names, rotation=45, ha='right')
# [Text(0, 0, 'Scratch Model'),
#  Text(1, 0, 'SF Model'),
#  Text(2, 0, 'Combined Model'),
#  Text(3, 0, 'MD Model')]

# %%
figure = plt.figure(figsize=(3.5, 2.5))
ax = figure.add_subplot(111)

name_dict = {'raw-1' : 'Scratch Model', 'md-1': 'MD Model', 'isolated-1' : 'SF Model', 'combined-1': 'Combined Model',
             'raw-2' : 'Scratch Model', 'md-2': 'MD Model', 'isolated-2' : 'SF Model', 'combined-2': 'Combined Model'}

rmse_data = []
for column in df.columns[5:]:
    rmses = df[column].tolist()
    rmse = sum(rmses) / len(rmses)
    model_name = name_dict.get(column, column)  
    rmse_data.append((model_name, rmse))
    print(column)

rmse_data.sort(key=lambda x: x[1])
model_names, rmse_values = zip(*rmse_data)

bars = ax.bar(model_names, rmse_values)

for bar, color in zip(bars, plt.rcParams['axes.prop_cycle'].by_key()['color']):
    bar.set_color(color)

ax.set_ylabel('RMSE')
ax.set_xticklabels(model_names, rotation=45, ha='right')
# Out:
# raw-1
# mds-only-1
# sf-only-1
# mds-1
# /tmp/ipykernel_2939943/304040594.py:24: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(model_names, rotation=45, ha='right')
# [Text(0, 0, 'Scratch Model'),
#  Text(1, 0, 'SF Model'),
#  Text(2, 0, 'Combined Model'),
#  Text(3, 0, 'MD Model')]

# %%
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 120    False
# 121    False
# 122    False
# 123    False
# 124    False
# Length: 125, dtype: bool
